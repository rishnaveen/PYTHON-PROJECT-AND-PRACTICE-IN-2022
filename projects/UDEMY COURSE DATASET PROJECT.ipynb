# %%
import pandas as pd

# %% [markdown]
# # UDEMY COURSE DATASET

# %%
data = pd.read_csv('C:\\Users\\Win\\Desktop\\7. Udemy Courses.csv')
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# # Q) What are diffrent subjects for which udemy is offering course

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
#data.groupby('subject').sum()
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# # Q) What subject has the maximum number of courses

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
data.subject.value_counts().max()
# Out:
# 1200

# %% [markdown]
# # Q)Show all the courses which are free of cost

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data[data.is_paid==False]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...    False
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...    False
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...    False
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...    False
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...    False
# 3678     552700    Your Second Course on Piano: Two Handed Playing    False
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions    False
#
# ...

# %% [markdown]
# # Q) Show all the courses which are paid

# %%
data.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
data[data.is_paid == True]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %% [markdown]
# # Q) what are top selling courses ?

# %%
data.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
data.sort_values('num_subscribers', ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp    False
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0    False
# ...         ...                                                ...      ...
# 2290    1223240  Learn Pirates of the Caribbean by Ear on the P...    False
# 1267    1258666                Financial Statement Auditing Cycles    False
# 2070    1215926                Kickstarter success in 5 easy steps    False
# 1931    1247992  Introduction to Project Management for Finance...    False
# 3165    1087466  Stop Creditors from Harassing you and Avoid Ba...    False
#
# ...

# %% [markdown]
# # Q) Show all the courses of Graphic design where the price is below 100 ?

# %%
data[(data.subject == 'Graphic Design') & (data.price < '100')]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...    False
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...    False
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...    False
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...    False
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...    False
# 3678     552700    Your Second Course on Piano: Two Handed Playing    False
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions    False
#
# ...

# %% [markdown]
# # Q) List out all the courses that are related with "Python"

# %%
data[data.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...    False
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...    False
# 814      631128  Complete Python Web Course: Build 8 Python Web...    False
# 842      186096  Core: A Web App Reference Guide for Django, Py...    False
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming    False
# 1969     902888          Investment Portfolio Analysis with Python    False
# 2294     391546        Learn Python and Django: Payment Processing    False
# 2295    1063722            Learn Python Django - A Hands-On Course    False
# 2341     546848  Learn to code in Python and learn Adobe Photos...    False
# 2906     368340    Professional Python Web Development Using Flask    False
# ...

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...    False
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...    False
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...    False
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...    False
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %% [markdown]
# # Q) What are the courses that publised in year 2015 ?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...    False
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data['published_timestamp'] = pd.to_datetime(data.published_timestamp)

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...    False
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments

# %%
data['year'] = data['published_timestamp'].dt.year

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...    False
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...    False
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...    False
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...    False
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...    False
# 3678     552700    Your Second Course on Piano: Two Handed Playing    False
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions    False
#
# ...

# %%
data[data.year == 2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...    False
# 16       302450        10 Numbers Every Business Owner Should Know    False
# 19       384928  101 Blues riffs - learn how the harmonica supe...    False
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...    False
# 26       486240      2 Easy Steps To Investment And Avoiding Traps    False
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano    False
# 3676     498488  Your First Successful Forex Trades - With Case...    False
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...    False
# 3678     552700    Your Second Course on Piano: Two Handed Playing    False
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...    False
#
# ...

# %% [markdown]
# # Q) What are the max. number of sunscribers for each level of courses ?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...    False
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...    False
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject  year
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments  2014
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments  2017

# %%
data.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
data.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
data.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels            False  Free           268923        27445           544
# Beginner Level        False  Free           161029         5924           779
# Expert Level          False    95             5172          249           157
# Intermediate Level    False  Free            29167         3326           320
#
# ...
