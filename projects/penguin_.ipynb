# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from skimage import data

# %%
data=pd.read_csv("/content/drive/MyDrive/dataset/penguins.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df=pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df["bill_length_mm"].fillna( method ='ffill', limit = 1, inplace = True)
df["bill_depth_mm"].fillna( method ='ffill', limit = 1, inplace = True)
df["flipper_length_mm"].fillna( method ='ffill', limit = 1, inplace = True)
df["body_mass_g"].fillna( method ='ffill', limit = 1, inplace = True)
df["sex"].fillna( method ='ffill', limit = 1, inplace = True)

# %%
df["sex"].fillna( method ='ffill', limit = 1, inplace = True)

# %%
df.info
# Out:
# <bound method DataFrame.info of     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# ...

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  2
# dtype: int64

# %%
df.shape
# Out:
# (344, 7)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  2
# dtype: int64

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.shape
# Out:
# (344, 7)

# %%
df['island'].value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
df['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# MALE      175
# FEMALE    167
# Name: sex, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset
data = {'Adelie':152, 'Dream':124, 'Chinstrap':68}
species = list(data.keys())
island = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(species, island, color ='maroon',
		width = 0.4)

plt.xlabel("species")
plt.ylabel("island")
plt.title("island and species")
plt.show()

# %%
import seaborn as sns

# %%
df[['bill_length_mm','bill_depth_mm','flipper_length_mm']].plot(figsize=(15,5))

# %%
import seaborn as sns
sns.pairplot(data=df,hue='island')
plt.show()

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.island.value_counts().plot(kind='pie',autopct='%.2f',figsize=[10,20])

# %%
plot_color_gradients(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g', 'sex'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-912ce8443102> in <module>()
# ----> 1 plot_color_gradients(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#       2        'flipper_length_mm', 'body_mass_g', 'sex'])
#
# NameError: name 'plot_color_gradients' is not defined

# %%
dsax = sns.boxplot(x="island", y="flipper_length_mm",
                 data=df, palette="Set3")
ax = sns.swarmplot(x="island", y="flipper_length_mm", data=df, color=".25")

# %%
ax = sns.boxplot(x="species", y="flipper_length_mm",
                 data=df, palette="Set3")

# %%
import seaborn as sns

sns.FacetGrid(df,hue="island", size=8)\
.map(plt.scatter,"bill_depth_mm","flipper_length_mm")\
.add_legend()

# %%
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
x = ['species', 'island', 'bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g', 'sex']
plt.stem(x, markerfmt = 's', linefmt='--', basefmt = ':', use_line_collection=True)
plt.show()
# plt.stem(x, y, markerfmt = 's', linefmt='--', basefmt = ':', use_line_collection=True)
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from cycler import cycler
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.linestyle'] = '--'
data = np.random.randn(50)
plt.plot(data)

# %%
df.columns

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=df['species'].values #🡪 Converting to numpy Array
y=df['island'].values
N = 344 #Number of cases
colors = np.random.rand(N) # 🡪 Generate random values
area = (30 * np.random.rand(N))**2 # 0 to 15 point radii
plt.scatter(x,y,c=colors,s=area,alpha=0.5) #→ Create Scatterplot
plt.xlabel("species") #→ x label
plt.ylabel("'island'") #→ y label
#'''Add label for data points'''
for i, label in enumerate(data['species']):
  plt.annotate(label,(x[i],y[i]))
  plt.title("Scatter Plot") #🡪 Set plot title

# %%
#Plot the distribution of group experience with density=1:
nbins = 20
n,bins, patches = plt.hist("flipper_length_mm", bins=nbins, density=1)
# Add labels to the axes and a title:
plt.xlabel("flipper_length_mm")
plt.ylabel("body_mass_g")
plt.title("flipper_lenth_mm and body_mass_g")
# Draw a green vertical line in the graph at the average experience:
plt.axvline(x=flipper_lenth_mm.mean(), linewidth=3, color = 'g')
# Compute the mean and standard deviation of the dataset:
mu =flipper_lenth_mm.mean()
sigma = flipper_lenth_mm.std()
# Add a best-fit line for the normal distribution:
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma
* (bins - mu))**2))
# Plot the normal distribution:
plt.plot(bins, y, '--')
